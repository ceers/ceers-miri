# %%
# Correct latent for F2100W (June-28 exposures)

# %%
import sep
from astropy.io import fits
from glob import glob
from astropy.wcs import WCS
from astropy.table import Table
from astropy.coordinates.sky_coordinate import SkyCoord
from astropy.convolution import Tophat2DKernel
from scipy.ndimage import binary_dilation

import os
os.environ['CRDS_PATH']= '/Users/users/gyang/gyang/crds_cache/jwst_pub'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds-pub.stsci.edu'

from jwst.pipeline import Image3Pipeline
from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level3 import Asn_Lv3Image

# %run -i '../../tools/astrometry/srcor.ipynb'
# %run -i 'super_bg.ipynb'

# %%
# Get the June-28 file names
fnames = sorted( glob('../data/reduced/jw01345052001_02101_0000?_mirimage_cal_stprm_bgsub.fits') )
# List to save detected source catalogs and segmentation 
cats, segs, whts, wcss = [], [], [], []
# Iterate over each file
for idx, fname in enumerate(fnames):
    # Perform source detection
    src, dat, wht, bkg, seg = det_src(fname, sigma_threshold=1., minarea=10, cr_sigclip=4,
                                      clean_edge=False)
    # Convert x,y to ra, dec
    ras, decs = [], []
    wcs = WCS(fits.getheader(fname, 'sci'))
    for cor in wcs.pixel_to_world(src['x']-1, src['y']-1):
        ras.append( cor.ra.deg )
        decs.append( cor.dec.deg )
    cat = Table( [src['id'], src['x'], src['y'], ras, decs],
                  names=['id', 'x', 'y', 'ra', 'dec'] )
    print(len(cat))
    # Save the results
    segs.append(seg)
    cats.append(cat)
    whts.append(wht)
    wcss.append(wcs)
    # Write out segmentation and wheight maps
    fits.writeto('../data/persistence/seg_all_%d.fits' %(idx+1), seg,
                 header=fits.getheader(fname, 'sci'), overwrite=True)    
    fits.writeto('../data/persistence/wht_%d.fits' %(idx+1), wht,
                 header=fits.getheader(fname, 'sci'), overwrite=True)
# Out:
# 2022-09-12 16:13:56,035 - stpipe - WARNING - /net/dataserver3/data/users/gyang/conda_env/jwst_pipeline/lib/python3.10/site-packages/astropy/wcs/wcs.py:725: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-06-28T07:49:01.462' from MJD-BEG.
# Set DATE-AVG to '2022-06-28T07:57:33.457' from MJD-AVG.
# Set DATE-END to '2022-06-28T08:06:05.452' from MJD-END'.
#   warnings.warn(
#
# 2022-09-12 16:13:56,037 - stpipe - WARNING - /net/dataserver3/data/users/gyang/conda_env/jwst_pipeline/lib/python3.10/site-packages/astropy/wcs/wcs.py:725: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -73.412891 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -37.794096 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1730760512.408 from OBSGEO-[XYZ]'.
#   warnings.warn(
# 296
# 2022-09-12 16:13:57,378 - stpipe - WARNING - /net/dataserver3/data/users/gyang/conda_env/jwst_pipeline/lib/python3.10/site-packages/astropy/wcs/wcs.py:725: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-06-28T08:07:28.725' from MJD-BEG.
# Set DATE-AVG to '2022-06-28T08:16:00.720' from MJD-AVG.
# Set DATE-END to '2022-06-28T08:24:32.715' from MJD-END'.
#   warnings.warn(
#
# 2022-09-12 16:13:57,379 - stpipe - WARNING - /net/dataserver3/data/users/gyang/conda_env/jwst_pipeline/lib/python3.10/site-packages/astropy/wcs/wcs.py:725: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -73.410718 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -37.795705 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1730772551.630 from OBSGEO-[XYZ]'.
#   warnings.warn(
# 132
# 2022-09-12 16:13:58,551 - stpipe - WARNING - /net/dataserver3/data/users/gyang/conda_env/jwst_pipeline/lib/python3.10/site-packages/astropy/wcs/wcs.py:725: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-06-28T08:25:58.804' from MJD-BEG.
# Set DATE-AVG to '2022-06-28T08:34:30.799' from MJD-AVG.
# Set DATE-END to '2022-06-28T08:43:02.794' from MJD-END'.
#   warnings.warn(
#
# 2022-09-12 16:13:58,552 - stpipe - WARNING - /net/dataserver3/data/users/gyang/conda_env/jwst_pipeline/lib/python3.10/site-packages/astropy/wcs/wcs.py:725: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -73.408661 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -37.797228 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1730783969.615 from OBSGEO-[XYZ]'.
#   warnings.warn(
# 128

# %%
# If a source is matched to any sources in the other two catalogs
# it's considered as a real source 
# We only have to do for the 1st dither, as its latent should be the strongest
idx0 = 0
# Get the index of the other two catalogs
oth_idxs = list(range(3))
oth_idxs.remove(idx0)
idx1, idx2 = oth_idxs[0], oth_idxs[1]
# Match cat0 with cat1 and cat2, respectively 
rad = 0.5
cat0_cat1_idxs, cat1_cat0_idxs, cat01_ds = match(cats[idx0]['ra'], cats[idx0]['dec'],
                                          cats[idx1]['ra'], cats[idx1]['dec'], rad, opt=0)
cat0_cat2_idxs, cat2_cat0_idxs, cat02_ds = match(cats[idx0]['ra'], cats[idx0]['dec'],
                                          cats[idx2]['ra'], cats[idx2]['dec'], rad, opt=0)
# Get real sources (1-based ID)
real_ids = np.unique( np.append(cats[idx0]['id'][cat0_cat1_idxs],
                                cats[idx0]['id'][cat0_cat2_idxs]) )
# Futher assume a source as real if it low weight in the other two dithers
wht_thresh = 0.2
for row in cats[idx0]:
    # If it's already a real source
    if row['id'] in real_ids: continue
    # Get the detector coordinates in the other two dithers
    x1, y1 = wcss[idx1].world_to_pixel( SkyCoord( [row['ra']], [row['dec']], unit='deg' ) )
    x1, y1 = round(x1[0]), round(y1[0])
    x2, y2 = wcss[idx2].world_to_pixel( SkyCoord( [row['ra']], [row['dec']], unit='deg' ) )
    x2, y2 = round(x2[0]), round(y2[0])    
    # Check if the position has low weights in both wht maps
    if (y1>=0) and (x1>=0) and (y1<whts[idx1].shape[0]) and (x1<whts[idx1].shape[1]):
        wht1 = whts[idx1][y1, x1]
    else: wht1 = np.nan
    if (y2>=0) and (x2>=0) and (y2<whts[idx2].shape[0]) and (x2<whts[idx2].shape[1]):
        wht2 = whts[idx2][y2, x2]
    else: wht2 = np.nan    
    wht1_thresh = wht_thresh*np.nanmax(whts[idx1])
    wht2_thresh = wht_thresh*np.nanmax(whts[idx2])
    
    if (np.isnan(wht1) or wht1<wht1_thresh) and (np.isnan(wht2) or wht2<wht2_thresh):
        real_ids = np.append(real_ids, row['id'])
        
# Remove sources near the brightest persistence 
real_Sidxs = []
for src_Sidx, real_id in enumerate(real_ids):
    # Get the source position
    src_idx = np.where( cats[idx0]['id'] == real_id )[0][0]
    x, y = cats[idx0]['x'][src_idx], cats[idx0]['y'][src_idx]
    # real sources should be far away from the brightest persistence 
    if (x-481)**2 + (y-567)**2 > 107**2: real_Sidxs.append(src_Sidx)
real_ids = real_ids[real_Sidxs]
        
# Clean the real sources in segmentation map
seg = segs[idx0].copy()
for real_id in real_ids:
    seg[seg==real_id] = 0 

# Write out the segmentation map
fits.writeto('../data/persistence/seg_fake_%d.fits' %(idx0+1), seg,
             header=fits.getheader(fnames[idx0], 'sci'), overwrite=True)

# Do segmentation dilation as a master mask map
#footprint = Tophat2DKernel(radius=1)
#seg = binary_dilation(seg, footprint.array).astype(int)
fits.writeto('../data/persistence/latent_mask.fits', seg, overwrite=True)
# Out:
# Multi-one match:  45  sources
# Multi-one match:  39  sources

# %%
import jwst
from jwst import datamodels
# %run -i 'run_tkreg.ipynb'

# Create an association 
asn = dict( asn_from_list.asn_from_list(fnames, rule=Asn_Lv3Image, 
            product_name='l3_results', asn_type="image3") )
# Initialize stage 3 pipeline
# In the following, we use ".copy()" as input to avoid the input being changed 
img3 = Image3Pipeline()
# Load the data models
dms = datamodels.open(asn)

tkreg_res = run_tkreg(dms, img3, cr_sigclip=1, run2=False)

# match bkg
img3.skymatch.subtract = True
img3.skymatch.skymethod = 'local'
res = img3.skymatch.run(tkreg_res.copy())

# Reject cosmic-ray 
res = img3.outlier_detection.run(res)

# Apply the mask
#mask_map = fits.getdata('../data/persistence/latent_mask.fits')
#mask = mask_map!=0
#for exp_idx in range(len(res)):
#    res[exp_idx].data[mask] = 0
#    res[exp_idx].dq[mask] = 11 # the flag is rather some arbitrary bad 
#    res[exp_idx].err[mask] = np.inf
#    res[exp_idx].var_rnoise[mask] = np.inf

res = img3.resample(res)
# Output 
res.save('../data/persistence/merged_latent_not_masked.fits')

# Clean up cache
os.system('rm *.fits')
# Out:
# 2022-09-12 16:20:55,315 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-09-12 16:20:55,317 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-09-12 16:20:55,318 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-09-12 16:20:55,321 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-09-12 16:20:55,322 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-09-12 16:20:55,324 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-09-12 16:20:55,325 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-09-12 16:20:55,329 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False, 'class': ''}
#
#
# 2022-09-12 16:20:55,330 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-09-12 16:20:55,333 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True, 'override_drizpars': None, 'class': ''}
#
#
# 2022-09-12 16:20:55,334 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-09-12 16:20:55,336 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-09-12 16:20:55,337 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-09-12 16:21:00,895 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-09-12 16:21:00,898 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 1, 'use2dhist': True, 'separation': 0.01, 'tolerance': 0.5, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-09-12 16:21:00,907 - stpipe.Image3Pipeline.tweakreg - INFO - Detected 94 sources in jw01345052001_02101_00001_mirimage_cal_stprm_bgsub.fits.
# 2022-09-12 16:21:00,918 - stpipe.Image3Pipeline.tweakreg - INFO - Detected 73 sources in jw01345052001_02101_00002_mirimage_cal_stprm_bgsub.fits.
# 2022-09-12 16:21:00,929 - stpipe.Image3Pipeline.tweakreg - INFO - Detected 71 sources in jw01345052001_02101_00003_mirimage_cal_stprm_bgsub.fits.
# 2022-09-12 16:21:00,942 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:00,943 - stpipe.Image3Pipeline.tweakreg - INFO - Number of image groups to be aligned: 3.
# 2022-09-12 16:21:00,943 - stpipe.Image3Pipeline.tweakreg - INFO - Image groups:
# 2022-09-12 16:21:00,969 - stpipe.Image3Pipeline.tweakreg - INFO - * Images in GROUP 'jw01345052001_02101_00001_mirimage_cal_stprm_bgsub':
# 2022-09-12 16:21:00,970 - stpipe.Image3Pipeline.tweakreg - INFO -      jw01345052001_02101_00001_mirimage_cal_stprm_bgsub
# 2022-09-12 16:21:00,995 - stpipe.Image3Pipeline.tweakreg - INFO - * Images in GROUP 'jw01345052001_02101_00002_mirimage_cal_stprm_bgsub':
# 2022-09-12 16:21:00,995 - stpipe.Image3Pipeline.tweakreg - INFO -      jw01345052001_02101_00002_mirimage_cal_stprm_bgsub
# 2022-09-12 16:21:01,021 - stpipe.Image3Pipeline.tweakreg - INFO - * Images in GROUP 'jw01345052001_02101_00003_mirimage_cal_stprm_bgsub':
# 2022-09-12 16:21:01,022 - stpipe.Image3Pipeline.tweakreg - INFO -      jw01345052001_02101_00003_mirimage_cal_stprm_bgsub
# 2022-09-12 16:21:01,022 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:01,023 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:01,024 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() started on 2022-09-12 16:21:01.023566
# 2022-09-12 16:21:01,024 - stpipe.Image3Pipeline.tweakreg - INFO -       Version 0.7.4
# 2022-09-12 16:21:01,026 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:01,097 - stpipe.Image3Pipeline.tweakreg - INFO - Selected image 'GROUP ID: jw01345052001_02101_00001_mirimage_cal_stprm_bgsub' as reference image
# 2022-09-12 16:21:01,102 - stpipe.Image3Pipeline.tweakreg - INFO - Aligning image catalog 'GROUP ID: jw01345052001_02101_00002_mirimage_cal_stprm_bgsub' to the reference catalog.
# 2022-09-12 16:21:01,222 - stpipe.Image3Pipeline.tweakreg - INFO - Matching sources from 'jw01345052001_02101_00002_mirimage_cal_stprm_bgsub' catalog with sources from the reference 'jw01345052001_02101_00001_mirimage_cal_stprm_bgsub' catalog.
# 2022-09-12 16:21:01,223 - stpipe.Image3Pipeline.tweakreg - INFO - Computing initial guess for X and Y shifts...
# 2022-09-12 16:21:01,225 - stpipe.Image3Pipeline.tweakreg - INFO - Found initial X and Y shifts of 0.009893, -0.1979 with significance of 15.06 and 37 matches.
# 2022-09-12 16:21:01,227 - stpipe.Image3Pipeline.tweakreg - INFO - Found 22 matches for 'GROUP ID: jw01345052001_02101_00002_mirimage_cal_stprm_bgsub'...
# 2022-09-12 16:21:01,228 - stpipe.Image3Pipeline.tweakreg - INFO - Performing 'rshift' fit
# 2022-09-12 16:21:01,230 - stpipe.Image3Pipeline.tweakreg - INFO - Computed 'rshift' fit for GROUP ID: jw01345052001_02101_00002_mirimage_cal_stprm_bgsub:
# 2022-09-12 16:21:01,231 - stpipe.Image3Pipeline.tweakreg - INFO - XSH: -0.00343105  YSH: -0.0204054    ROT: 0.0453898    SCALE: 1
# 2022-09-12 16:21:01,231 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:01,232 - stpipe.Image3Pipeline.tweakreg - INFO - FIT RMSE: 0.130104   FIT MAE: 0.10454
# 2022-09-12 16:21:01,232 - stpipe.Image3Pipeline.tweakreg - INFO - Final solution based on 21 objects.
# 2022-09-12 16:21:01,273 - stpipe.Image3Pipeline.tweakreg - INFO - Aligning image catalog 'GROUP ID: jw01345052001_02101_00003_mirimage_cal_stprm_bgsub' to the reference catalog.
# 2022-09-12 16:21:01,392 - stpipe.Image3Pipeline.tweakreg - INFO - Matching sources from 'jw01345052001_02101_00003_mirimage_cal_stprm_bgsub' catalog with sources from the reference 'jw01345052001_02101_00001_mirimage_cal_stprm_bgsub' catalog.
# 2022-09-12 16:21:01,393 - stpipe.Image3Pipeline.tweakreg - INFO - Computing initial guess for X and Y shifts...
# 2022-09-12 16:21:01,396 - stpipe.Image3Pipeline.tweakreg - INFO - Found initial X and Y shifts of -0.01333, 0.01333 with significance of 17.15 and 33 matches.
# 2022-09-12 16:21:01,397 - stpipe.Image3Pipeline.tweakreg - INFO - Found 21 matches for 'GROUP ID: jw01345052001_02101_00003_mirimage_cal_stprm_bgsub'...
# 2022-09-12 16:21:01,398 - stpipe.Image3Pipeline.tweakreg - INFO - Performing 'rshift' fit
# 2022-09-12 16:21:01,400 - stpipe.Image3Pipeline.tweakreg - INFO - Computed 'rshift' fit for GROUP ID: jw01345052001_02101_00003_mirimage_cal_stprm_bgsub:
# 2022-09-12 16:21:01,401 - stpipe.Image3Pipeline.tweakreg - INFO - XSH: -0.00616878  YSH: -0.000934264    ROT: 0.039983    SCALE: 1
# 2022-09-12 16:21:01,402 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:01,402 - stpipe.Image3Pipeline.tweakreg - INFO - FIT RMSE: 0.0956214   FIT MAE: 0.0778945
# 2022-09-12 16:21:01,403 - stpipe.Image3Pipeline.tweakreg - INFO - Final solution based on 20 objects.
# 2022-09-12 16:21:01,444 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:01,445 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() ended on 2022-09-12 16:21:01.444023
# 2022-09-12 16:21:01,445 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() TOTAL RUN TIME: 0:00:00.420457
# 2022-09-12 16:21:01,446 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:01,475 - stpipe.Image3Pipeline.tweakreg - INFO - Using user-provided reference catalog: /Users/users/gyang/gyang/sterm_bkup/ownCloud/notebook/ceers/data/CANDELS_F160W_v2.cat
# 2022-09-12 16:21:01,605 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:01,606 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() started on 2022-09-12 16:21:01.605613
# 2022-09-12 16:21:01,607 - stpipe.Image3Pipeline.tweakreg - INFO -       Version 0.7.4
# 2022-09-12 16:21:01,607 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:01,973 - stpipe.Image3Pipeline.tweakreg - INFO - Aligning image catalog 'GROUP ID: 876543' to the reference catalog.
# 2022-09-12 16:21:02,099 - stpipe.Image3Pipeline.tweakreg - INFO - Matching sources from 'jw01345052001_02101_0000' catalog with sources from the reference 'Unnamed' catalog.
# 2022-09-12 16:21:02,101 - stpipe.Image3Pipeline.tweakreg - INFO - Computing initial guess for X and Y shifts...
# 2022-09-12 16:21:02,134 - stpipe.Image3Pipeline.tweakreg - INFO - Found initial X and Y shifts of 0.009891, -0.01163 with significance of 26.23 and 169 matches.
# 2022-09-12 16:21:02,141 - stpipe.Image3Pipeline.tweakreg - INFO - Found 36 matches for 'GROUP ID: 876543'...
# 2022-09-12 16:21:02,142 - stpipe.Image3Pipeline.tweakreg - INFO - Performing 'rshift' fit
# 2022-09-12 16:21:02,145 - stpipe.Image3Pipeline.tweakreg - INFO - Computed 'rshift' fit for GROUP ID: 876543:
# 2022-09-12 16:21:02,145 - stpipe.Image3Pipeline.tweakreg - INFO - XSH: 0.100534  YSH: -0.0539172    ROT: -0.0428732    SCALE: 1
# 2022-09-12 16:21:02,146 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:02,147 - stpipe.Image3Pipeline.tweakreg - INFO - FIT RMSE: 0.122   FIT MAE: 0.100371
# 2022-09-12 16:21:02,147 - stpipe.Image3Pipeline.tweakreg - INFO - Final solution based on 35 objects.
# 2022-09-12 16:21:02,268 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:02,269 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() ended on 2022-09-12 16:21:02.268822
# 2022-09-12 16:21:02,270 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() TOTAL RUN TIME: 0:00:00.663209
# 2022-09-12 16:21:02,270 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2022-09-12 16:21:02,447 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-09-12 16:21:03,143 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-09-12 16:21:03,146 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'local', 'match_down': True, 'subtract': True, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-09-12 16:21:03,234 - stpipe.Image3Pipeline.skymatch - INFO -
# 2022-09-12 16:21:03,235 - stpipe.Image3Pipeline.skymatch - INFO - ***** jwst.skymatch.skymatch.match() started on 2022-09-12 16:21:03.234448
# 2022-09-12 16:21:03,236 - stpipe.Image3Pipeline.skymatch - INFO -
# 2022-09-12 16:21:03,236 - stpipe.Image3Pipeline.skymatch - INFO - Sky computation method: 'local'
# 2022-09-12 16:21:03,237 - stpipe.Image3Pipeline.skymatch - INFO - Sky subtraction from image data: ON
# 2022-09-12 16:21:03,238 - stpipe.Image3Pipeline.skymatch - INFO -
# 2022-09-12 16:21:03,238 - stpipe.Image3Pipeline.skymatch - INFO - ----  Sky values computed per image and/or image groups.
# 2022-09-12 16:21:03,289 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=jw01345052001_02101_00001_mirimage_cal_stprm_bgsub.fits. Sky background: -0.0101366 (old=0, delta=-0.0101366)
# 2022-09-12 16:21:03,292 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=jw01345052001_02101_00002_mirimage_cal_stprm_bgsub.fits. Sky background: -0.00985196 (old=0, delta=-0.00985196)
# 2022-09-12 16:21:03,294 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=jw01345052001_02101_00003_mirimage_cal_stprm_bgsub.fits. Sky background: -0.00366147 (old=0, delta=-0.00366147)
# 2022-09-12 16:21:03,295 - stpipe.Image3Pipeline.skymatch - INFO -
# 2022-09-12 16:21:03,295 - stpipe.Image3Pipeline.skymatch - INFO - ***** jwst.skymatch.skymatch.match() ended on 2022-09-12 16:21:03.295083
# 2022-09-12 16:21:03,296 - stpipe.Image3Pipeline.skymatch - INFO - ***** jwst.skymatch.skymatch.match() TOTAL RUN TIME: 0:00:00.060635
# 2022-09-12 16:21:03,297 - stpipe.Image3Pipeline.skymatch - INFO -
# 2022-09-12 16:21:03,314 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-09-12 16:21:03,630 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-09-12 16:21:03,632 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2022-09-12 16:21:03,640 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 3 inputs
# 2022-09-12 16:21:03,641 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter kernel: square
# 2022-09-12 16:21:03,642 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter pixfrac: 1.0
# 2022-09-12 16:21:03,643 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter fillval: INDEF
# 2022-09-12 16:21:03,643 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter weight_type: ivm
# 2022-09-12 16:21:03,783 - stpipe.Image3Pipeline.outlier_detection - INFO - 1 exposures to drizzle together
# 2022-09-12 16:21:04,483 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:05,169 - stpipe.Image3Pipeline.outlier_detection - INFO - Exposure jw01345052001_02101_00001_mirimage_cal_stprm_outlier_i2d.fits saved to file
# 2022-09-12 16:21:05,176 - stpipe.Image3Pipeline.outlier_detection - INFO - 1 exposures to drizzle together
# 2022-09-12 16:21:06,339 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:07,234 - stpipe.Image3Pipeline.outlier_detection - INFO - Exposure jw01345052001_02101_00002_mirimage_cal_stprm_outlier_i2d.fits saved to file
# 2022-09-12 16:21:07,241 - stpipe.Image3Pipeline.outlier_detection - INFO - 1 exposures to drizzle together
# 2022-09-12 16:21:08,065 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:08,670 - stpipe.Image3Pipeline.outlier_detection - INFO - Exposure jw01345052001_02101_00003_mirimage_cal_stprm_outlier_i2d.fits saved to file
# 2022-09-12 16:21:12,493 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-09-12 16:21:13,320 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1042, 1057)
# 2022-09-12 16:21:15,223 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1042, 1057)
# 2022-09-12 16:21:17,301 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1042, 1057)
# 2022-09-12 16:21:17,991 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-09-12 16:21:18,374 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 14755 (1.40%)
# 2022-09-12 16:21:18,738 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 5393 (0.51%)
# 2022-09-12 16:21:19,527 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4615 (0.44%)
# 2022-09-12 16:21:19,540 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-09-12 16:21:19,887 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ModelContainer>,).
# 2022-09-12 16:21:19,890 - stpipe.Image3Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}
# 2022-09-12 16:21:19,925 - stpipe.Image3Pipeline.resample - INFO - Drizpars reference file: /Users/users/gyang/gyang/crds_cache/jwst_pub/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-09-12 16:21:19,961 - stpipe.Image3Pipeline.resample - INFO - Driz parameter kernel: square
# 2022-09-12 16:21:19,961 - stpipe.Image3Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2022-09-12 16:21:19,962 - stpipe.Image3Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2022-09-12 16:21:19,963 - stpipe.Image3Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2022-09-12 16:21:20,229 - stpipe.Image3Pipeline.resample - INFO - Blending metadata for l3_results
# 2022-09-12 16:21:21,651 - stpipe.Image3Pipeline.resample - INFO - Resampling science data
# 2022-09-12 16:21:22,378 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:23,450 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:24,524 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:24,873 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2022-09-12 16:21:25,591 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:26,661 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:27,731 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:28,086 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-09-12 16:21:28,814 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:29,891 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:30,968 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:31,322 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-09-12 16:21:32,045 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:33,124 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:34,206 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1042, 1057)
# 2022-09-12 16:21:34,583 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  215.028059301 52.981691920 215.068516066 52.960787400 215.103751625 52.985490643 215.063288773 53.006407122
# 2022-09-12 16:21:34,592 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 0

# %%
# Out:
# 0
